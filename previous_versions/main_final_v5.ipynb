# %% [markdown]
# # Final Main Implementation v.5

# %% [markdown]
# > This is a the main CNN implementation to recognize images of sign language digits.

# %%
# libraries:
import numpy as np
from sklearn.model_selection import train_test_split, KFold
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# %% [markdown]
# ### Loading and preprocessing the data

# %%
# Defining a CNN model
def build_cnn(input_shape=(64, 64, 1), num_classes=10):
    model = models.Sequential([
        # Convolutional Layers
        # Stem
        layers.Conv2D(32, (3,3), activation='relu', input_shape=input_shape),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2,2)),
        #layers.Dropout(0.1),
        
        # Core
        layers.Conv2D(64, (3,3), activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2,2)),
        #layers.Dropout(0.1),

        layers.Conv2D(128, (3,3), activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2,2)),
        #layers.Dropout(0.1),

        # Head
        layers.Flatten(),
        layers.Dropout(0.5),
        layers.Dense(64, activation='relu', kernel_regularizer='l2'),
        layers.Dense(num_classes, activation='softmax')
    ])
    
    model.compile(
        optimizer=optimizers.Adam(learning_rate=0.001),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    
    return model

# %%
# Load images and labels
X = np.load('data/X.npy').astype('float32')
y = np.load('data/Y.npy')

# %%
# Add channel dimension (grayscale)
X = X.reshape(-1, 64, 64, 1)  # New shape: (2062, 64, 64, 1)

# %%
k = 10  # Typical value, but you can experiment
kf = KFold(n_splits=k, shuffle=True, random_state=42)

# %%
# Data Augmentation: helps increase the diversity of training data
# by applying random transformations like rotation and zoom
train_datagen = ImageDataGenerator(
    rotation_range=15,           # Randomly rotate images in the range (degrees)
    zoom_range=0.1,              # Randomly zoom images
    width_shift_range=0.1,       # Randomly shift images horizontally
    height_shift_range=0.1,       # Randomly shift images vertically
    cval=0                       # Fill value for empty areas
)

val_datagen = ImageDataGenerator()

# %% [markdown]
# ### Main CNN Implementation with k-fold CV

# %%
# Lists to store history from each fold
accuracies = []
all_train_acc = []
all_val_acc = []
all_train_loss = []
all_val_loss = []

# %%
callbacks = [
    EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3)
]

# %%
for train_index, val_index in kf.split(X):
    # Split data
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y[train_index], y[val_index]

    # Convert one-hot labels to integers 
    y_train = np.argmax(y_train, axis=1)
    y_val = np.argmax(y_val, axis=1)

    # Create generators
    train_generator = train_datagen.flow(X_train, y_train, batch_size=32)
    val_generator = val_datagen.flow(X_val, y_val, batch_size=32)
    
    # Create and train model (you'll need to reinitialize your model each time)
    model = build_cnn()  # Your model creation function
    history = model.fit(train_generator, 
                       validation_data=val_generator,
                       epochs=30,
                       callbacks=callbacks)
    
    # Evaluate and store accuracy
    val_acc = model.evaluate(X_val, y_val)[1]
    accuracies.append(val_acc)

    # Store metrics
    all_train_acc.append(history.history['accuracy'])
    all_val_acc.append(history.history['val_accuracy'])
    all_train_loss.append(history.history['loss'])
    all_val_loss.append(history.history['val_loss'])
# Out:
# Epoch 1/30
# /Users/anthamorious/Library/Mobile Documents/com~apple~CloudDocs/University/University of Houston/Semesters/🎓 Spring 2025/🌹 COSC 4337 - Data Science II/Project/Final report/COSC4337-project-main/.venv/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /Users/anthamorious/Library/Mobile Documents/com~apple~CloudDocs/University/University of Houston/Semesters/🎓 Spring 2025/🌹 COSC 4337 - Data Science II/Project/Final report/COSC4337-project-main/.venv/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.3244 - loss: 3.6981 - val_accuracy: 0.1932 - val_loss: 6.6266 - learning_rate: 0.0010
# Epoch 2/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.6231 - loss: 2.2871 - val_accuracy: 0.1063 - val_loss: 8.2825 - learning_rate: 0.0010
# Epoch 3/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.7099 - loss: 1.8203 - val_accuracy: 0.1063 - val_loss: 5.3879 - learning_rate: 0.0010
# Epoch 4/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.8024 - loss: 1.4872 - val_accuracy: 0.2415 - val_loss: 4.1897 - learning_rate: 0.0010
# Epoch 5/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.8589 - loss: 1.2164 - val_accuracy: 0.1836 - val_loss: 4.5221 - learning_rate: 0.0010
# Epoch 6/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.8811 - loss: 1.0022 - val_accuracy: 0.1063 - val_loss: 5.5345 - learning_rate: 0.0010
# Epoch 7/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.8816 - loss: 0.9189 - val_accuracy: 0.2077 - val_loss: 3.8182 - learning_rate: 0.0010
# Epoch 8/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.9033 - loss: 0.8107 - val_accuracy: 0.2319 - val_loss: 3.5607 - learning_rate: 0.0010
# Epoch 9/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9108 - loss: 0.7249 - val_accuracy: 0.5121 - val_loss: 1.6377 - learning_rate: 0.0010
# Epoch 10/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9240 - loss: 0.6786 - val_accuracy: 0.6715 - val_loss: 1.1396 - learning_rate: 0.0010
# Epoch 11/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.9114 - loss: 0.6854 - val_accuracy: 0.8406 - val_loss: 0.8163 - learning_rate: 0.0010
# Epoch 12/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9394 - loss: 0.5480 - val_accuracy: 0.7923 - val_loss: 0.8333 - learning_rate: 0.0010
# Epoch 13/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.9379 - loss: 0.5545 - val_accuracy: 0.9614 - val_loss: 0.4725 - learning_rate: 0.0010
# Epoch 14/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.9453 - loss: 0.5077 - val_accuracy: 0.9855 - val_loss: 0.4191 - learning_rate: 0.0010
# Epoch 15/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9617 - loss: 0.4623 - val_accuracy: 0.6715 - val_loss: 1.6494 - learning_rate: 0.0010
# Epoch 16/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - accuracy: 0.9512 - loss: 0.4885 - val_accuracy: 0.9662 - val_loss: 0.4391 - learning_rate: 0.0010
# Epoch 17/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - accuracy: 0.9621 - loss: 0.4141 - val_accuracy: 0.9903 - val_loss: 0.3391 - learning_rate: 0.0010
# Epoch 18/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - accuracy: 0.9484 - loss: 0.4315 - val_accuracy: 0.9807 - val_loss: 0.3556 - learning_rate: 0.0010
# Epoch 19/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.9642 - loss: 0.4016 - val_accuracy: 0.9034 - val_loss: 0.6930 - learning_rate: 0.0010
# Epoch 20/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9739 - loss: 0.3647 - val_accuracy: 0.9807 - val_loss: 0.3334 - learning_rate: 0.0010
# Epoch 21/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9612 - loss: 0.3820 - val_accuracy: 0.9952 - val_loss: 0.3050 - learning_rate: 0.0010
# Epoch 22/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - accuracy: 0.9655 - loss: 0.3900 - val_accuracy: 0.9758 - val_loss: 0.3394 - learning_rate: 0.0010
# Epoch 23/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.9494 - loss: 0.4714 - val_accuracy: 0.9469 - val_loss: 0.4560 - learning_rate: 0.0010
# Epoch 24/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - accuracy: 0.9438 - loss: 0.4589 - val_accuracy: 0.8986 - val_loss: 0.6263 - learning_rate: 0.0010
# Epoch 25/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9633 - loss: 0.4367 - val_accuracy: 0.9855 - val_loss: 0.3271 - learning_rate: 5.0000e-04
# Epoch 26/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.9815 - loss: 0.3516 - val_accuracy: 0.9903 - val_loss: 0.2838 - learning_rate: 5.0000e-04
# Epoch 27/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9798 - loss: 0.3446 - val_accuracy: 0.9903 - val_loss: 0.2617 - learning_rate: 5.0000e-04
# Epoch 28/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.9821 - loss: 0.2943 - val_accuracy: 0.9952 - val_loss: 0.2527 - learning_rate: 5.0000e-04
# Epoch 29/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9875 - loss: 0.2774 - val_accuracy: 0.9855 - val_loss: 0.2570 - learning_rate: 5.0000e-04
# Epoch 30/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - accuracy: 0.9870 - loss: 0.2584 - val_accuracy: 0.9758 - val_loss: 0.2667 - learning_rate: 5.0000e-04
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9981 - loss: 0.2488
# Epoch 1/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - accuracy: 0.2778 - loss: 3.8453 - val_accuracy: 0.1546 - val_loss: 4.9988 - learning_rate: 0.0010
# Epoch 2/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.5818 - loss: 2.3391 - val_accuracy: 0.0918 - val_loss: 5.2265 - learning_rate: 0.0010
# Epoch 3/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.7179 - loss: 1.7746 - val_accuracy: 0.1208 - val_loss: 4.2710 - learning_rate: 0.0010
# Epoch 4/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - accuracy: 0.7798 - loss: 1.4475 - val_accuracy: 0.1594 - val_loss: 4.1269 - learning_rate: 0.0010
# Epoch 5/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.8225 - loss: 1.2476 - val_accuracy: 0.3285 - val_loss: 2.7616 - learning_rate: 0.0010
# Epoch 6/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.8457 - loss: 1.0545 - val_accuracy: 0.3140 - val_loss: 2.7943 - learning_rate: 0.0010
# Epoch 7/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.8971 - loss: 0.8708 - val_accuracy: 0.2754 - val_loss: 2.6641 - learning_rate: 0.0010
# Epoch 8/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.9193 - loss: 0.7944 - val_accuracy: 0.7053 - val_loss: 1.2337 - learning_rate: 0.0010
# Epoch 9/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.9155 - loss: 0.7059 - val_accuracy: 0.8116 - val_loss: 0.8990 - learning_rate: 0.0010
# Epoch 10/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.9245 - loss: 0.6668 - val_accuracy: 0.8551 - val_loss: 0.7527 - learning_rate: 0.0010
# Epoch 11/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.9217 - loss: 0.6585 - val_accuracy: 0.8889 - val_loss: 0.6826 - learning_rate: 0.0010
# Epoch 12/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.9332 - loss: 0.5772 - val_accuracy: 0.9565 - val_loss: 0.5064 - learning_rate: 0.0010
# Epoch 13/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.9344 - loss: 0.5676 - val_accuracy: 0.9372 - val_loss: 0.4775 - learning_rate: 0.0010
# Epoch 14/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.9438 - loss: 0.5127 - val_accuracy: 0.9855 - val_loss: 0.3985 - learning_rate: 0.0010
# Epoch 15/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.9558 - loss: 0.4872 - val_accuracy: 0.9807 - val_loss: 0.3927 - learning_rate: 0.0010
# Epoch 16/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - accuracy: 0.9547 - loss: 0.4467 - val_accuracy: 0.9807 - val_loss: 0.3857 - learning_rate: 0.0010
# Epoch 17/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.9453 - loss: 0.4787 - val_accuracy: 0.9517 - val_loss: 0.4669 - learning_rate: 0.0010
# Epoch 18/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.9577 - loss: 0.4387 - val_accuracy: 0.9662 - val_loss: 0.3560 - learning_rate: 0.0010
# Epoch 19/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - accuracy: 0.9664 - loss: 0.3893 - val_accuracy: 0.9614 - val_loss: 0.4477 - learning_rate: 0.0010
# Epoch 20/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - accuracy: 0.9455 - loss: 0.4290 - val_accuracy: 0.9517 - val_loss: 0.4168 - learning_rate: 0.0010
# Epoch 21/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.9537 - loss: 0.4205 - val_accuracy: 0.9614 - val_loss: 0.3507 - learning_rate: 0.0010
# Epoch 22/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.9543 - loss: 0.3921 - val_accuracy: 0.9855 - val_loss: 0.3214 - learning_rate: 0.0010
# Epoch 23/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.9539 - loss: 0.3969 - val_accuracy: 0.9614 - val_loss: 0.3524 - learning_rate: 0.0010
# Epoch 24/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.9624 - loss: 0.3803 - val_accuracy: 0.8454 - val_loss: 0.8654 - learning_rate: 0.0010
# Epoch 25/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - accuracy: 0.9646 - loss: 0.3813 - val_accuracy: 0.9565 - val_loss: 0.3712 - learning_rate: 0.0010
# Epoch 26/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.9676 - loss: 0.3542 - val_accuracy: 0.9807 - val_loss: 0.2935 - learning_rate: 5.0000e-04
# Epoch 27/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.9787 - loss: 0.3096 - val_accuracy: 0.9903 - val_loss: 0.2620 - learning_rate: 5.0000e-04
# Epoch 28/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.9817 - loss: 0.2787 - val_accuracy: 0.9855 - val_loss: 0.2391 - learning_rate: 5.0000e-04
# Epoch 29/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.9764 - loss: 0.2755 - val_accuracy: 0.9952 - val_loss: 0.2112 - learning_rate: 5.0000e-04
# Epoch 30/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - accuracy: 0.9860 - loss: 0.2489 - val_accuracy: 0.9807 - val_loss: 0.2399 - learning_rate: 5.0000e-04
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9981 - loss: 0.2032
# Epoch 1/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.2792 - loss: 3.7867 - val_accuracy: 0.0971 - val_loss: 7.0961 - learning_rate: 0.0010
# Epoch 2/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.5901 - loss: 2.3013 - val_accuracy: 0.0971 - val_loss: 7.7175 - learning_rate: 0.0010
# Epoch 3/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.7170 - loss: 1.7881 - val_accuracy: 0.1553 - val_loss: 5.5840 - learning_rate: 0.0010
# Epoch 4/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.7683 - loss: 1.4564 - val_accuracy: 0.1359 - val_loss: 4.8699 - learning_rate: 0.0010
# Epoch 5/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.8271 - loss: 1.2007 - val_accuracy: 0.1748 - val_loss: 4.1240 - learning_rate: 0.0010
# Epoch 6/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.8717 - loss: 1.0070 - val_accuracy: 0.1553 - val_loss: 4.1797 - learning_rate: 0.0010
# Epoch 7/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.8813 - loss: 0.9354 - val_accuracy: 0.1796 - val_loss: 3.9996 - learning_rate: 0.0010
# Epoch 8/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.9017 - loss: 0.8085 - val_accuracy: 0.2427 - val_loss: 3.5647 - learning_rate: 0.0010
# Epoch 9/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.9119 - loss: 0.7071 - val_accuracy: 0.4320 - val_loss: 1.9513 - learning_rate: 0.0010
# Epoch 10/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 0.9354 - loss: 0.6149 - val_accuracy: 0.8641 - val_loss: 0.7514 - learning_rate: 0.0010
# Epoch 11/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9419 - loss: 0.5918 - val_accuracy: 0.7476 - val_loss: 1.1085 - learning_rate: 0.0010
# Epoch 12/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.9388 - loss: 0.6046 - val_accuracy: 0.8350 - val_loss: 0.8187 - learning_rate: 0.0010
# Epoch 13/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.9631 - loss: 0.4952 - val_accuracy: 0.8689 - val_loss: 0.6814 - learning_rate: 0.0010
# Epoch 14/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.9325 - loss: 0.5532 - val_accuracy: 0.9612 - val_loss: 0.4534 - learning_rate: 0.0010
# Epoch 15/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9528 - loss: 0.4468 - val_accuracy: 0.9806 - val_loss: 0.3948 - learning_rate: 0.0010
# Epoch 16/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.9590 - loss: 0.4641 - val_accuracy: 0.9466 - val_loss: 0.4522 - learning_rate: 0.0010
# Epoch 17/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.9407 - loss: 0.4680 - val_accuracy: 0.9175 - val_loss: 0.5957 - learning_rate: 0.0010
# Epoch 18/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9442 - loss: 0.4459 - val_accuracy: 0.9660 - val_loss: 0.4239 - learning_rate: 0.0010
# Epoch 19/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.9669 - loss: 0.4013 - val_accuracy: 0.9903 - val_loss: 0.3302 - learning_rate: 5.0000e-04
# Epoch 20/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.9741 - loss: 0.3711 - val_accuracy: 0.9806 - val_loss: 0.3418 - learning_rate: 5.0000e-04
# Epoch 21/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9581 - loss: 0.3863 - val_accuracy: 0.9806 - val_loss: 0.3193 - learning_rate: 5.0000e-04
# Epoch 22/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - accuracy: 0.9769 - loss: 0.3232 - val_accuracy: 0.9757 - val_loss: 0.3042 - learning_rate: 5.0000e-04
# Epoch 23/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.9780 - loss: 0.3170 - val_accuracy: 0.9903 - val_loss: 0.2629 - learning_rate: 5.0000e-04
# Epoch 24/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.9854 - loss: 0.2752 - val_accuracy: 0.9806 - val_loss: 0.2555 - learning_rate: 5.0000e-04
# Epoch 25/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.9841 - loss: 0.2556 - val_accuracy: 0.9903 - val_loss: 0.2434 - learning_rate: 5.0000e-04
# Epoch 26/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.9849 - loss: 0.2542 - val_accuracy: 0.9951 - val_loss: 0.2215 - learning_rate: 5.0000e-04
# Epoch 27/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.9810 - loss: 0.2667 - val_accuracy: 0.9709 - val_loss: 0.2538 - learning_rate: 5.0000e-04
# Epoch 28/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 0.9773 - loss: 0.2451 - val_accuracy: 0.9903 - val_loss: 0.2302 - learning_rate: 5.0000e-04
# Epoch 29/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.9802 - loss: 0.2405 - val_accuracy: 0.9563 - val_loss: 0.2951 - learning_rate: 5.0000e-04
# Epoch 30/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - accuracy: 0.9850 - loss: 0.2332 - val_accuracy: 0.9903 - val_loss: 0.2025 - learning_rate: 2.5000e-04
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9932 - loss: 0.1988
# Epoch 1/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - accuracy: 0.2644 - loss: 3.9541 - val_accuracy: 0.1117 - val_loss: 9.5686 - learning_rate: 0.0010
# Epoch 2/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.6178 - loss: 2.1941 - val_accuracy: 0.1117 - val_loss: 9.9429 - learning_rate: 0.0010
# Epoch 3/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.7607 - loss: 1.6652 - val_accuracy: 0.1117 - val_loss: 7.9378 - learning_rate: 0.0010
# Epoch 4/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.8247 - loss: 1.3130 - val_accuracy: 0.1117 - val_loss: 6.1040 - learning_rate: 0.0010
# Epoch 5/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.8635 - loss: 1.0852 - val_accuracy: 0.3058 - val_loss: 3.1772 - learning_rate: 0.0010
# Epoch 6/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.9002 - loss: 0.9356 - val_accuracy: 0.2087 - val_loss: 3.4001 - learning_rate: 0.0010
# Epoch 7/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.9087 - loss: 0.7941 - val_accuracy: 0.3058 - val_loss: 2.3466 - learning_rate: 0.0010
# Epoch 8/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - accuracy: 0.9230 - loss: 0.6996 - val_accuracy: 0.4466 - val_loss: 1.9913 - learning_rate: 0.0010
# Epoch 9/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 76ms/step - accuracy: 0.9159 - loss: 0.6623 - val_accuracy: 0.6456 - val_loss: 1.3621 - learning_rate: 0.0010
# Epoch 10/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 107ms/step - accuracy: 0.9319 - loss: 0.6231 - val_accuracy: 0.9369 - val_loss: 0.5973 - learning_rate: 0.0010
# Epoch 11/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - accuracy: 0.9409 - loss: 0.5419 - val_accuracy: 0.9515 - val_loss: 0.5861 - learning_rate: 0.0010
# Epoch 12/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - accuracy: 0.9349 - loss: 0.5324 - val_accuracy: 0.8835 - val_loss: 0.6793 - learning_rate: 0.0010
# Epoch 13/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - accuracy: 0.9408 - loss: 0.4852 - val_accuracy: 0.9660 - val_loss: 0.4161 - learning_rate: 0.0010
# Epoch 14/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - accuracy: 0.9438 - loss: 0.4690 - val_accuracy: 0.9466 - val_loss: 0.5306 - learning_rate: 0.0010
# Epoch 15/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 11s 112ms/step - accuracy: 0.9636 - loss: 0.4281 - val_accuracy: 0.9320 - val_loss: 0.5149 - learning_rate: 0.0010
# Epoch 16/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 111ms/step - accuracy: 0.9447 - loss: 0.4566 - val_accuracy: 0.9466 - val_loss: 0.4971 - learning_rate: 0.0010
# Epoch 17/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 104ms/step - accuracy: 0.9483 - loss: 0.4283 - val_accuracy: 0.9854 - val_loss: 0.3775 - learning_rate: 5.0000e-04
# Epoch 18/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - accuracy: 0.9717 - loss: 0.3704 - val_accuracy: 0.9806 - val_loss: 0.3558 - learning_rate: 5.0000e-04
# Epoch 19/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step - accuracy: 0.9828 - loss: 0.3100 - val_accuracy: 0.9854 - val_loss: 0.3349 - learning_rate: 5.0000e-04
# Epoch 20/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - accuracy: 0.9758 - loss: 0.3079 - val_accuracy: 0.9660 - val_loss: 0.3537 - learning_rate: 5.0000e-04
# Epoch 21/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 106ms/step - accuracy: 0.9767 - loss: 0.2829 - val_accuracy: 0.9903 - val_loss: 0.2792 - learning_rate: 5.0000e-04
# Epoch 22/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step - accuracy: 0.9825 - loss: 0.2683 - val_accuracy: 0.9903 - val_loss: 0.3082 - learning_rate: 5.0000e-04
# Epoch 23/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - accuracy: 0.9738 - loss: 0.2634 - val_accuracy: 0.9903 - val_loss: 0.2669 - learning_rate: 5.0000e-04
# Epoch 24/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step - accuracy: 0.9724 - loss: 0.2684 - val_accuracy: 0.9903 - val_loss: 0.2386 - learning_rate: 5.0000e-04
# Epoch 25/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - accuracy: 0.9740 - loss: 0.2543 - val_accuracy: 0.9903 - val_loss: 0.2782 - learning_rate: 5.0000e-04
# Epoch 26/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - accuracy: 0.9848 - loss: 0.2385 - val_accuracy: 0.9951 - val_loss: 0.2554 - learning_rate: 5.0000e-04
# Epoch 27/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - accuracy: 0.9806 - loss: 0.2346 - val_accuracy: 0.9806 - val_loss: 0.2778 - learning_rate: 5.0000e-04
# Epoch 28/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9742 - loss: 0.2499 - val_accuracy: 0.9951 - val_loss: 0.2392 - learning_rate: 2.5000e-04
# Epoch 29/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 104ms/step - accuracy: 0.9851 - loss: 0.2050 - val_accuracy: 0.9854 - val_loss: 0.2396 - learning_rate: 2.5000e-04
# Epoch 30/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - accuracy: 0.9875 - loss: 0.1983 - val_accuracy: 0.9951 - val_loss: 0.2338 - learning_rate: 2.5000e-04
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9931 - loss: 0.2636
# Epoch 1/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 7s 103ms/step - accuracy: 0.2619 - loss: 3.9733 - val_accuracy: 0.1165 - val_loss: 4.1941 - learning_rate: 0.0010
# Epoch 2/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step - accuracy: 0.5621 - loss: 2.4656 - val_accuracy: 0.1165 - val_loss: 6.8629 - learning_rate: 0.0010
# Epoch 3/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - accuracy: 0.6889 - loss: 1.8944 - val_accuracy: 0.1165 - val_loss: 7.3235 - learning_rate: 0.0010
# Epoch 4/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - accuracy: 0.7769 - loss: 1.4683 - val_accuracy: 0.1165 - val_loss: 4.7670 - learning_rate: 0.0010
# Epoch 5/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - accuracy: 0.8528 - loss: 1.1985 - val_accuracy: 0.1893 - val_loss: 4.2352 - learning_rate: 5.0000e-04
# Epoch 6/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 104ms/step - accuracy: 0.8769 - loss: 1.0789 - val_accuracy: 0.1505 - val_loss: 3.3822 - learning_rate: 5.0000e-04
# Epoch 7/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step - accuracy: 0.8709 - loss: 1.0104 - val_accuracy: 0.4757 - val_loss: 2.0812 - learning_rate: 5.0000e-04
# Epoch 8/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step - accuracy: 0.9053 - loss: 0.8634 - val_accuracy: 0.3495 - val_loss: 2.2829 - learning_rate: 5.0000e-04
# Epoch 9/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - accuracy: 0.9272 - loss: 0.7735 - val_accuracy: 0.7864 - val_loss: 1.1043 - learning_rate: 5.0000e-04
# Epoch 10/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 105ms/step - accuracy: 0.9226 - loss: 0.7229 - val_accuracy: 0.8835 - val_loss: 0.8103 - learning_rate: 5.0000e-04
# Epoch 11/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 7s 112ms/step - accuracy: 0.9415 - loss: 0.6320 - val_accuracy: 0.9515 - val_loss: 0.5829 - learning_rate: 5.0000e-04
# Epoch 12/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - accuracy: 0.9376 - loss: 0.6187 - val_accuracy: 0.9466 - val_loss: 0.6205 - learning_rate: 5.0000e-04
# Epoch 13/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 104ms/step - accuracy: 0.9344 - loss: 0.6165 - val_accuracy: 0.9806 - val_loss: 0.4654 - learning_rate: 5.0000e-04
# Epoch 14/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - accuracy: 0.9472 - loss: 0.5502 - val_accuracy: 0.9854 - val_loss: 0.4355 - learning_rate: 5.0000e-04
# Epoch 15/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 104ms/step - accuracy: 0.9331 - loss: 0.5435 - val_accuracy: 0.9757 - val_loss: 0.4475 - learning_rate: 5.0000e-04
# Epoch 16/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - accuracy: 0.9506 - loss: 0.4954 - val_accuracy: 0.9612 - val_loss: 0.4301 - learning_rate: 5.0000e-04
# Epoch 17/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 104ms/step - accuracy: 0.9661 - loss: 0.4445 - val_accuracy: 0.9417 - val_loss: 0.4612 - learning_rate: 5.0000e-04
# Epoch 18/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 104ms/step - accuracy: 0.9557 - loss: 0.4436 - val_accuracy: 0.9612 - val_loss: 0.4076 - learning_rate: 5.0000e-04
# Epoch 19/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 104ms/step - accuracy: 0.9537 - loss: 0.4380 - val_accuracy: 0.9806 - val_loss: 0.3551 - learning_rate: 5.0000e-04
# Epoch 20/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - accuracy: 0.9601 - loss: 0.3996 - val_accuracy: 0.9709 - val_loss: 0.3355 - learning_rate: 5.0000e-04
# Epoch 21/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step - accuracy: 0.9711 - loss: 0.3630 - val_accuracy: 0.9223 - val_loss: 0.4958 - learning_rate: 5.0000e-04
# Epoch 22/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - accuracy: 0.9796 - loss: 0.3361 - val_accuracy: 0.9854 - val_loss: 0.2858 - learning_rate: 5.0000e-04
# Epoch 23/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 106ms/step - accuracy: 0.9617 - loss: 0.3566 - val_accuracy: 0.9806 - val_loss: 0.2925 - learning_rate: 5.0000e-04
# Epoch 24/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 105ms/step - accuracy: 0.9699 - loss: 0.3171 - val_accuracy: 0.9612 - val_loss: 0.3346 - learning_rate: 5.0000e-04
# Epoch 25/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 104ms/step - accuracy: 0.9697 - loss: 0.3353 - val_accuracy: 0.9854 - val_loss: 0.2836 - learning_rate: 5.0000e-04
# Epoch 26/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 105ms/step - accuracy: 0.9549 - loss: 0.3324 - val_accuracy: 0.9612 - val_loss: 0.3142 - learning_rate: 5.0000e-04
# Epoch 27/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 104ms/step - accuracy: 0.9624 - loss: 0.3285 - val_accuracy: 0.9563 - val_loss: 0.3428 - learning_rate: 5.0000e-04
# Epoch 28/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - accuracy: 0.9727 - loss: 0.2949 - val_accuracy: 0.9903 - val_loss: 0.2483 - learning_rate: 5.0000e-04
# Epoch 29/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - accuracy: 0.9742 - loss: 0.2966 - val_accuracy: 0.9757 - val_loss: 0.2714 - learning_rate: 5.0000e-04
# Epoch 30/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - accuracy: 0.9701 - loss: 0.2935 - val_accuracy: 0.9854 - val_loss: 0.2543 - learning_rate: 5.0000e-04
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9924 - loss: 0.2414
# Epoch 1/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 7s 105ms/step - accuracy: 0.2894 - loss: 3.7711 - val_accuracy: 0.0583 - val_loss: 4.6494 - learning_rate: 0.0010
# Epoch 2/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 104ms/step - accuracy: 0.6045 - loss: 2.3786 - val_accuracy: 0.1214 - val_loss: 5.2658 - learning_rate: 0.0010
# Epoch 3/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - accuracy: 0.6935 - loss: 1.9052 - val_accuracy: 0.1019 - val_loss: 5.0969 - learning_rate: 0.0010
# Epoch 4/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 87ms/step - accuracy: 0.7730 - loss: 1.5368 - val_accuracy: 0.1311 - val_loss: 5.0838 - learning_rate: 0.0010
# Epoch 5/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 105ms/step - accuracy: 0.8512 - loss: 1.2334 - val_accuracy: 0.1311 - val_loss: 5.0922 - learning_rate: 5.0000e-04
# Epoch 6/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.8632 - loss: 1.1011 - val_accuracy: 0.2184 - val_loss: 3.8717 - learning_rate: 5.0000e-04
# Epoch 7/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - accuracy: 0.8876 - loss: 0.9715 - val_accuracy: 0.2184 - val_loss: 3.4495 - learning_rate: 5.0000e-04
# Epoch 8/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 105ms/step - accuracy: 0.9072 - loss: 0.8825 - val_accuracy: 0.4709 - val_loss: 2.1173 - learning_rate: 5.0000e-04
# Epoch 9/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - accuracy: 0.9100 - loss: 0.7982 - val_accuracy: 0.7427 - val_loss: 1.2817 - learning_rate: 5.0000e-04
# Epoch 10/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - accuracy: 0.9121 - loss: 0.7773 - val_accuracy: 0.9272 - val_loss: 0.7395 - learning_rate: 5.0000e-04
# Epoch 11/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 105ms/step - accuracy: 0.9314 - loss: 0.6807 - val_accuracy: 0.9466 - val_loss: 0.5887 - learning_rate: 5.0000e-04
# Epoch 12/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 138ms/step - accuracy: 0.9418 - loss: 0.6074 - val_accuracy: 0.9612 - val_loss: 0.5249 - learning_rate: 5.0000e-04
# Epoch 13/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 106ms/step - accuracy: 0.9445 - loss: 0.5677 - val_accuracy: 0.9660 - val_loss: 0.4617 - learning_rate: 5.0000e-04
# Epoch 14/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 104ms/step - accuracy: 0.9507 - loss: 0.5401 - val_accuracy: 0.9806 - val_loss: 0.4076 - learning_rate: 5.0000e-04
# Epoch 15/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 105ms/step - accuracy: 0.9467 - loss: 0.5266 - val_accuracy: 0.9903 - val_loss: 0.3787 - learning_rate: 5.0000e-04
# Epoch 16/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 107ms/step - accuracy: 0.9504 - loss: 0.4938 - val_accuracy: 0.9757 - val_loss: 0.3905 - learning_rate: 5.0000e-04
# Epoch 17/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - accuracy: 0.9625 - loss: 0.4616 - val_accuracy: 0.9854 - val_loss: 0.3657 - learning_rate: 5.0000e-04
# Epoch 18/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 105ms/step - accuracy: 0.9697 - loss: 0.4123 - val_accuracy: 0.9903 - val_loss: 0.3129 - learning_rate: 5.0000e-04
# Epoch 19/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 104ms/step - accuracy: 0.9642 - loss: 0.4051 - val_accuracy: 0.9854 - val_loss: 0.3173 - learning_rate: 5.0000e-04
# Epoch 20/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 107ms/step - accuracy: 0.9616 - loss: 0.3909 - val_accuracy: 0.9854 - val_loss: 0.2927 - learning_rate: 5.0000e-04
# Epoch 21/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - accuracy: 0.9699 - loss: 0.3648 - val_accuracy: 0.9806 - val_loss: 0.3116 - learning_rate: 5.0000e-04
# Epoch 22/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - accuracy: 0.9735 - loss: 0.3377 - val_accuracy: 0.9903 - val_loss: 0.2691 - learning_rate: 5.0000e-04
# Epoch 23/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 104ms/step - accuracy: 0.9700 - loss: 0.3416 - val_accuracy: 0.9854 - val_loss: 0.2732 - learning_rate: 5.0000e-04
# Epoch 24/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - accuracy: 0.9770 - loss: 0.3215 - val_accuracy: 0.9612 - val_loss: 0.3363 - learning_rate: 5.0000e-04
# Epoch 25/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 95ms/step - accuracy: 0.9676 - loss: 0.3361 - val_accuracy: 0.9806 - val_loss: 0.2826 - learning_rate: 5.0000e-04
# Epoch 26/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - accuracy: 0.9774 - loss: 0.3007 - val_accuracy: 0.9903 - val_loss: 0.2489 - learning_rate: 2.5000e-04
# Epoch 27/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - accuracy: 0.9864 - loss: 0.2753 - val_accuracy: 0.9951 - val_loss: 0.2211 - learning_rate: 2.5000e-04
# Epoch 28/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - accuracy: 0.9765 - loss: 0.2737 - val_accuracy: 0.9806 - val_loss: 0.2271 - learning_rate: 2.5000e-04
# Epoch 29/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - accuracy: 0.9796 - loss: 0.2538 - val_accuracy: 0.9951 - val_loss: 0.2006 - learning_rate: 2.5000e-04
# Epoch 30/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - accuracy: 0.9790 - loss: 0.2585 - val_accuracy: 0.9903 - val_loss: 0.2029 - learning_rate: 2.5000e-04
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9964 - loss: 0.1967
# Epoch 1/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 106ms/step - accuracy: 0.2959 - loss: 3.6518 - val_accuracy: 0.1408 - val_loss: 5.4380 - learning_rate: 0.0010
# Epoch 2/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - accuracy: 0.6264 - loss: 2.2697 - val_accuracy: 0.1553 - val_loss: 6.5481 - learning_rate: 0.0010
# Epoch 3/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 104ms/step - accuracy: 0.7423 - loss: 1.7470 - val_accuracy: 0.1359 - val_loss: 7.7509 - learning_rate: 0.0010
# Epoch 4/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - accuracy: 0.7730 - loss: 1.4629 - val_accuracy: 0.1359 - val_loss: 7.0508 - learning_rate: 0.0010
# Epoch 5/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - accuracy: 0.8532 - loss: 1.1701 - val_accuracy: 0.1359 - val_loss: 7.2907 - learning_rate: 5.0000e-04
# Epoch 6/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - accuracy: 0.8832 - loss: 0.9967 - val_accuracy: 0.1408 - val_loss: 5.5934 - learning_rate: 5.0000e-04
# Epoch 7/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 105ms/step - accuracy: 0.9158 - loss: 0.8865 - val_accuracy: 0.1359 - val_loss: 4.6429 - learning_rate: 5.0000e-04
# Epoch 8/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - accuracy: 0.9203 - loss: 0.7972 - val_accuracy: 0.3447 - val_loss: 2.8694 - learning_rate: 5.0000e-04
# Epoch 9/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 105ms/step - accuracy: 0.9129 - loss: 0.7745 - val_accuracy: 0.6311 - val_loss: 1.5562 - learning_rate: 5.0000e-04
# Epoch 10/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - accuracy: 0.9303 - loss: 0.6647 - val_accuracy: 0.8301 - val_loss: 0.8447 - learning_rate: 5.0000e-04
# Epoch 11/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - accuracy: 0.9195 - loss: 0.6635 - val_accuracy: 0.9223 - val_loss: 0.6407 - learning_rate: 5.0000e-04
# Epoch 12/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 104ms/step - accuracy: 0.9404 - loss: 0.5787 - val_accuracy: 0.9272 - val_loss: 0.6098 - learning_rate: 5.0000e-04
# Epoch 13/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 104ms/step - accuracy: 0.9533 - loss: 0.5523 - val_accuracy: 0.9369 - val_loss: 0.5351 - learning_rate: 5.0000e-04
# Epoch 14/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - accuracy: 0.9468 - loss: 0.5168 - val_accuracy: 0.9757 - val_loss: 0.4316 - learning_rate: 5.0000e-04
# Epoch 15/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9479 - loss: 0.5032 - val_accuracy: 0.9806 - val_loss: 0.3900 - learning_rate: 5.0000e-04
# Epoch 16/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - accuracy: 0.9560 - loss: 0.4670 - val_accuracy: 0.9466 - val_loss: 0.4517 - learning_rate: 5.0000e-04
# Epoch 17/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9536 - loss: 0.4460 - val_accuracy: 0.9903 - val_loss: 0.3376 - learning_rate: 5.0000e-04
# Epoch 18/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9669 - loss: 0.3962 - val_accuracy: 0.9854 - val_loss: 0.3378 - learning_rate: 5.0000e-04
# Epoch 19/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - accuracy: 0.9656 - loss: 0.3969 - val_accuracy: 0.9903 - val_loss: 0.3123 - learning_rate: 5.0000e-04
# Epoch 20/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.9673 - loss: 0.3532 - val_accuracy: 0.9612 - val_loss: 0.3461 - learning_rate: 5.0000e-04
# Epoch 21/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.9596 - loss: 0.3666 - val_accuracy: 0.9806 - val_loss: 0.3231 - learning_rate: 5.0000e-04
# Epoch 22/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.9648 - loss: 0.3678 - val_accuracy: 0.9951 - val_loss: 0.2712 - learning_rate: 5.0000e-04
# Epoch 23/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.9628 - loss: 0.3485 - val_accuracy: 0.9903 - val_loss: 0.2572 - learning_rate: 5.0000e-04
# Epoch 24/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9573 - loss: 0.3574 - val_accuracy: 0.9903 - val_loss: 0.2587 - learning_rate: 5.0000e-04
# Epoch 25/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.9544 - loss: 0.3461 - val_accuracy: 0.9757 - val_loss: 0.3016 - learning_rate: 5.0000e-04
# Epoch 26/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.9594 - loss: 0.3470 - val_accuracy: 0.9757 - val_loss: 0.2782 - learning_rate: 5.0000e-04
# Epoch 27/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.9684 - loss: 0.3310 - val_accuracy: 0.9806 - val_loss: 0.2568 - learning_rate: 2.5000e-04
# Epoch 28/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.9851 - loss: 0.2865 - val_accuracy: 1.0000 - val_loss: 0.2259 - learning_rate: 2.5000e-04
# Epoch 29/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.9805 - loss: 0.2700 - val_accuracy: 0.9854 - val_loss: 0.2341 - learning_rate: 2.5000e-04
# Epoch 30/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.9854 - loss: 0.2587 - val_accuracy: 1.0000 - val_loss: 0.2046 - learning_rate: 2.5000e-04
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.2014
# Epoch 1/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - accuracy: 0.2786 - loss: 4.0180 - val_accuracy: 0.1359 - val_loss: 9.6273 - learning_rate: 0.0010
# Epoch 2/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.5744 - loss: 2.3617 - val_accuracy: 0.1359 - val_loss: 10.3850 - learning_rate: 0.0010
# Epoch 3/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - accuracy: 0.7109 - loss: 1.8234 - val_accuracy: 0.1359 - val_loss: 9.5985 - learning_rate: 0.0010
# Epoch 4/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.7791 - loss: 1.4373 - val_accuracy: 0.1359 - val_loss: 7.2056 - learning_rate: 0.0010
# Epoch 5/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.8425 - loss: 1.1704 - val_accuracy: 0.1359 - val_loss: 4.1422 - learning_rate: 0.0010
# Epoch 6/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.8660 - loss: 1.0394 - val_accuracy: 0.1893 - val_loss: 3.3919 - learning_rate: 0.0010
# Epoch 7/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.8925 - loss: 0.8814 - val_accuracy: 0.2427 - val_loss: 2.5819 - learning_rate: 0.0010
# Epoch 8/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.8989 - loss: 0.7846 - val_accuracy: 0.4612 - val_loss: 1.8001 - learning_rate: 0.0010
# Epoch 9/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.9116 - loss: 0.7453 - val_accuracy: 0.7476 - val_loss: 1.0882 - learning_rate: 0.0010
# Epoch 10/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.9220 - loss: 0.7082 - val_accuracy: 0.7621 - val_loss: 1.0189 - learning_rate: 0.0010
# Epoch 11/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - accuracy: 0.9222 - loss: 0.6319 - val_accuracy: 0.9272 - val_loss: 0.6374 - learning_rate: 0.0010
# Epoch 12/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.9423 - loss: 0.5721 - val_accuracy: 0.8592 - val_loss: 0.6832 - learning_rate: 0.0010
# Epoch 13/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9272 - loss: 0.5809 - val_accuracy: 0.9806 - val_loss: 0.4084 - learning_rate: 0.0010
# Epoch 14/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9409 - loss: 0.5053 - val_accuracy: 0.8883 - val_loss: 0.5685 - learning_rate: 0.0010
# Epoch 15/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.9586 - loss: 0.4651 - val_accuracy: 0.9612 - val_loss: 0.4373 - learning_rate: 0.0010
# Epoch 16/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.9585 - loss: 0.4321 - val_accuracy: 0.9757 - val_loss: 0.3507 - learning_rate: 0.0010
# Epoch 17/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9527 - loss: 0.4243 - val_accuracy: 0.9757 - val_loss: 0.3200 - learning_rate: 0.0010
# Epoch 18/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.9588 - loss: 0.4154 - val_accuracy: 0.9757 - val_loss: 0.3269 - learning_rate: 0.0010
# Epoch 19/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.9622 - loss: 0.4240 - val_accuracy: 0.9320 - val_loss: 0.5207 - learning_rate: 0.0010
# Epoch 20/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9512 - loss: 0.4154 - val_accuracy: 0.9903 - val_loss: 0.2964 - learning_rate: 0.0010
# Epoch 21/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9518 - loss: 0.4204 - val_accuracy: 0.9660 - val_loss: 0.3592 - learning_rate: 0.0010
# Epoch 22/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.9591 - loss: 0.3978 - val_accuracy: 0.9223 - val_loss: 0.4440 - learning_rate: 0.0010
# Epoch 23/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.9516 - loss: 0.3951 - val_accuracy: 0.8738 - val_loss: 0.7575 - learning_rate: 0.0010
# Epoch 24/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.9646 - loss: 0.3875 - val_accuracy: 0.9806 - val_loss: 0.3175 - learning_rate: 5.0000e-04
# Epoch 25/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9758 - loss: 0.3326 - val_accuracy: 0.9903 - val_loss: 0.2663 - learning_rate: 5.0000e-04
# Epoch 26/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.9840 - loss: 0.3005 - val_accuracy: 0.9854 - val_loss: 0.2525 - learning_rate: 5.0000e-04
# Epoch 27/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9807 - loss: 0.2728 - val_accuracy: 0.9854 - val_loss: 0.2309 - learning_rate: 5.0000e-04
# Epoch 28/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.9848 - loss: 0.2464 - val_accuracy: 1.0000 - val_loss: 0.1884 - learning_rate: 5.0000e-04
# Epoch 29/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9850 - loss: 0.2429 - val_accuracy: 0.9951 - val_loss: 0.1906 - learning_rate: 5.0000e-04
# Epoch 30/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9762 - loss: 0.2564 - val_accuracy: 1.0000 - val_loss: 0.1829 - learning_rate: 5.0000e-04
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.1814
# Epoch 1/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.2751 - loss: 3.7396 - val_accuracy: 0.1408 - val_loss: 4.6601 - learning_rate: 0.0010
# Epoch 2/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.5702 - loss: 2.3906 - val_accuracy: 0.1602 - val_loss: 4.7629 - learning_rate: 0.0010
# Epoch 3/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.7065 - loss: 1.8107 - val_accuracy: 0.3107 - val_loss: 4.1230 - learning_rate: 0.0010
# Epoch 4/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.7971 - loss: 1.4745 - val_accuracy: 0.2864 - val_loss: 3.8158 - learning_rate: 0.0010
# Epoch 5/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.8087 - loss: 1.2704 - val_accuracy: 0.2718 - val_loss: 3.1119 - learning_rate: 0.0010
# Epoch 6/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.8693 - loss: 1.0801 - val_accuracy: 0.3447 - val_loss: 2.7021 - learning_rate: 0.0010
# Epoch 7/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 0.9054 - loss: 0.9023 - val_accuracy: 0.2233 - val_loss: 2.6559 - learning_rate: 0.0010
# Epoch 8/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9045 - loss: 0.8145 - val_accuracy: 0.2621 - val_loss: 2.3867 - learning_rate: 0.0010
# Epoch 9/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.9179 - loss: 0.7342 - val_accuracy: 0.5777 - val_loss: 1.3625 - learning_rate: 0.0010
# Epoch 10/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9288 - loss: 0.6606 - val_accuracy: 0.9078 - val_loss: 0.6588 - learning_rate: 0.0010
# Epoch 11/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 76ms/step - accuracy: 0.9132 - loss: 0.6537 - val_accuracy: 0.8786 - val_loss: 0.7271 - learning_rate: 0.0010
# Epoch 12/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9502 - loss: 0.5332 - val_accuracy: 0.9903 - val_loss: 0.4554 - learning_rate: 0.0010
# Epoch 13/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9481 - loss: 0.5530 - val_accuracy: 0.9466 - val_loss: 0.4914 - learning_rate: 0.0010
# Epoch 14/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9312 - loss: 0.5774 - val_accuracy: 0.9660 - val_loss: 0.4701 - learning_rate: 0.0010
# Epoch 15/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.9475 - loss: 0.5199 - val_accuracy: 0.9660 - val_loss: 0.4218 - learning_rate: 0.0010
# Epoch 16/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.9476 - loss: 0.4963 - val_accuracy: 0.9854 - val_loss: 0.3744 - learning_rate: 0.0010
# Epoch 17/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 0.9605 - loss: 0.4549 - val_accuracy: 0.9175 - val_loss: 0.5257 - learning_rate: 0.0010
# Epoch 18/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 0.9657 - loss: 0.4435 - val_accuracy: 0.9126 - val_loss: 0.5780 - learning_rate: 0.0010
# Epoch 19/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.9642 - loss: 0.4003 - val_accuracy: 0.9757 - val_loss: 0.3627 - learning_rate: 0.0010
# Epoch 20/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.9486 - loss: 0.4228 - val_accuracy: 0.9854 - val_loss: 0.3225 - learning_rate: 0.0010
# Epoch 21/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 0.9776 - loss: 0.3664 - val_accuracy: 0.9515 - val_loss: 0.3787 - learning_rate: 0.0010
# Epoch 22/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 0.9647 - loss: 0.4001 - val_accuracy: 0.9660 - val_loss: 0.3828 - learning_rate: 0.0010
# Epoch 23/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.9553 - loss: 0.4181 - val_accuracy: 0.9806 - val_loss: 0.3570 - learning_rate: 0.0010
# Epoch 24/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.9563 - loss: 0.4249 - val_accuracy: 0.9951 - val_loss: 0.3029 - learning_rate: 5.0000e-04
# Epoch 25/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.9668 - loss: 0.3619 - val_accuracy: 0.9951 - val_loss: 0.2729 - learning_rate: 5.0000e-04
# Epoch 26/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.9856 - loss: 0.3051 - val_accuracy: 0.9903 - val_loss: 0.2473 - learning_rate: 5.0000e-04
# Epoch 27/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.9850 - loss: 0.2842 - val_accuracy: 1.0000 - val_loss: 0.2245 - learning_rate: 5.0000e-04
# Epoch 28/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.9832 - loss: 0.2651 - val_accuracy: 0.9951 - val_loss: 0.2331 - learning_rate: 5.0000e-04
# Epoch 29/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.9777 - loss: 0.2661 - val_accuracy: 0.9951 - val_loss: 0.2025 - learning_rate: 5.0000e-04
# Epoch 30/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.9820 - loss: 0.2353 - val_accuracy: 0.9903 - val_loss: 0.1892 - learning_rate: 5.0000e-04
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9952 - loss: 0.1844
# Epoch 1/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - accuracy: 0.2518 - loss: 4.0846 - val_accuracy: 0.0874 - val_loss: 7.5016 - learning_rate: 0.0010
# Epoch 2/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.5573 - loss: 2.4018 - val_accuracy: 0.0874 - val_loss: 7.4996 - learning_rate: 0.0010
# Epoch 3/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.6896 - loss: 1.8574 - val_accuracy: 0.1068 - val_loss: 5.5631 - learning_rate: 0.0010
# Epoch 4/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.7762 - loss: 1.4754 - val_accuracy: 0.1019 - val_loss: 4.3961 - learning_rate: 0.0010
# Epoch 5/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.8222 - loss: 1.1616 - val_accuracy: 0.1019 - val_loss: 4.9318 - learning_rate: 0.0010
# Epoch 6/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.8758 - loss: 0.9896 - val_accuracy: 0.1214 - val_loss: 4.0221 - learning_rate: 0.0010
# Epoch 7/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.8941 - loss: 0.8505 - val_accuracy: 0.2621 - val_loss: 3.3230 - learning_rate: 0.0010
# Epoch 8/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 0.9082 - loss: 0.7559 - val_accuracy: 0.5097 - val_loss: 1.8267 - learning_rate: 0.0010
# Epoch 9/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9264 - loss: 0.6712 - val_accuracy: 0.6796 - val_loss: 1.3215 - learning_rate: 0.0010
# Epoch 10/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.9302 - loss: 0.6386 - val_accuracy: 0.8981 - val_loss: 0.7139 - learning_rate: 0.0010
# Epoch 11/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.9295 - loss: 0.6364 - val_accuracy: 0.9417 - val_loss: 0.6186 - learning_rate: 0.0010
# Epoch 12/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 0.9428 - loss: 0.5745 - val_accuracy: 0.9757 - val_loss: 0.4919 - learning_rate: 0.0010
# Epoch 13/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.9373 - loss: 0.5372 - val_accuracy: 0.9515 - val_loss: 0.5621 - learning_rate: 0.0010
# Epoch 14/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.9436 - loss: 0.4952 - val_accuracy: 0.9078 - val_loss: 0.6672 - learning_rate: 0.0010
# Epoch 15/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.9491 - loss: 0.4749 - val_accuracy: 0.9612 - val_loss: 0.5106 - learning_rate: 0.0010
# Epoch 16/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.9601 - loss: 0.4467 - val_accuracy: 0.9854 - val_loss: 0.4065 - learning_rate: 5.0000e-04
# Epoch 17/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.9662 - loss: 0.3952 - val_accuracy: 0.9854 - val_loss: 0.3770 - learning_rate: 5.0000e-04
# Epoch 18/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9686 - loss: 0.3706 - val_accuracy: 0.9709 - val_loss: 0.3622 - learning_rate: 5.0000e-04
# Epoch 19/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.9687 - loss: 0.3393 - val_accuracy: 0.9903 - val_loss: 0.3282 - learning_rate: 5.0000e-04
# Epoch 20/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9734 - loss: 0.3220 - val_accuracy: 0.9903 - val_loss: 0.3200 - learning_rate: 5.0000e-04
# Epoch 21/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.9730 - loss: 0.2985 - val_accuracy: 0.9903 - val_loss: 0.3062 - learning_rate: 5.0000e-04
# Epoch 22/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9761 - loss: 0.2903 - val_accuracy: 0.9903 - val_loss: 0.3000 - learning_rate: 5.0000e-04
# Epoch 23/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.9777 - loss: 0.2678 - val_accuracy: 0.9854 - val_loss: 0.2859 - learning_rate: 5.0000e-04
# Epoch 24/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.9721 - loss: 0.2698 - val_accuracy: 0.9854 - val_loss: 0.2802 - learning_rate: 5.0000e-04
# Epoch 25/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.9756 - loss: 0.2678 - val_accuracy: 0.9612 - val_loss: 0.3130 - learning_rate: 5.0000e-04
# Epoch 26/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.9743 - loss: 0.2536 - val_accuracy: 0.9854 - val_loss: 0.2702 - learning_rate: 5.0000e-04
# Epoch 27/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.9818 - loss: 0.2518 - val_accuracy: 0.9806 - val_loss: 0.2735 - learning_rate: 5.0000e-04
# Epoch 28/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.9852 - loss: 0.2361 - val_accuracy: 0.9951 - val_loss: 0.2498 - learning_rate: 5.0000e-04
# Epoch 29/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.9838 - loss: 0.2264 - val_accuracy: 0.9854 - val_loss: 0.2643 - learning_rate: 5.0000e-04
# Epoch 30/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.9792 - loss: 0.2294 - val_accuracy: 0.9903 - val_loss: 0.2413 - learning_rate: 5.0000e-04
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9932 - loss: 0.2268

# %%
model.save('sign_language_digits.h5')  # Save the trained model
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ### Viewing CNN Statistics Accuracy & Loss

# %%
def plot_avg_accuracy(train_acc, val_acc):
    avg_train_acc = np.mean(train_acc, axis=0)
    avg_val_acc = np.mean(val_acc, axis=0)
    
    plt.figure(figsize=(10, 5))
    plt.plot(avg_train_acc, label='Training Accuracy')
    plt.plot(avg_val_acc, label='Validation Accuracy')
    plt.title('Average Training & Validation Accuracy Across Folds')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
def plot_avg_loss(train_loss, val_loss):
    avg_train_loss = np.mean(train_loss, axis=0)
    avg_val_loss = np.mean(val_loss, axis=0)
    
    plt.figure(figsize=(10, 5))
    plt.plot(avg_train_loss, label='Training Loss')
    plt.plot(avg_val_loss, label='Validation Loss')
    plt.title('Average Training & Validation Loss Across Folds')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
def plot_individual_folds(metric, title, ylabel):
    plt.figure(figsize=(10, 5))
    for i, fold_metric in enumerate(metric):
        plt.plot(fold_metric, label=f'Fold {i+1}')
    plt.title(title)
    plt.xlabel('Epoch')
    plt.ylabel(ylabel)
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
def plot_overlaid_folds(train_metric, val_metric, metric_name):
    plt.figure(figsize=(12, 6))
    
    # Plot all training metrics
    for i, fold_metric in enumerate(train_metric):
        plt.plot(fold_metric, color='blue', alpha=0.2, linestyle='-')
    
    # Plot all validation metrics
    for i, fold_metric in enumerate(val_metric):
        plt.plot(fold_metric, color='orange', alpha=0.2, linestyle='-')
    
    # Plot averages
    plt.plot(np.mean(train_metric, axis=0), color='blue', 
             linewidth=2, label='Avg Training')
    plt.plot(np.mean(val_metric, axis=0), color='orange', 
             linewidth=2, label='Avg Validation')
    
    plt.title(f'Training & Validation {metric_name} Across Folds')
    plt.xlabel('Epoch')
    plt.ylabel(metric_name)
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
print(f"Average validation accuracy: {np.mean(accuracies):.2%}")
# Out:
# Average validation accuracy: 99.42%

# %%
# Plotting average accuracy
plot_avg_accuracy(all_train_acc, all_val_acc)

# %%
# Plot individual folds accuracy
plot_individual_folds(all_train_acc, 'Training Accuracy per Fold', 'Accuracy')
plot_individual_folds(all_val_acc, 'Validation Accuracy per Fold', 'Accuracy')

# %%
# Plotting average loss
plot_avg_loss(all_train_loss, all_val_loss)

# %%
# Plot individual folds loss
plot_individual_folds(all_train_loss, 'Training Loss per Fold', 'Loss')
plot_individual_folds(all_val_loss, 'Validation Loss per Fold', 'Loss')

# %%
plot_overlaid_folds(all_train_acc, all_val_acc, 'Accuracy')

# %%
plot_overlaid_folds(all_train_loss, all_val_loss, 'Loss')

# %% [markdown]
# ### Evaluating Model Predictions

# %%
# Initialize lists to store all predictions and true labels
all_y_true = []
all_y_pred = []

# %%
for fold, (train_index, val_index) in enumerate(kf.split(X)):
    print(f"\nEvaluating Fold {fold + 1}/{k}")
    
    # Get validation data
    X_val = X[val_index]
    y_val = y[val_index]
    
    # Convert one-hot if needed
    if y_val.ndim > 1:
        y_val = np.argmax(y_val, axis=1)
    
    # Create generator with same preprocessing as validation
    val_generator = val_datagen.flow(X_val, y_val, batch_size=32, shuffle=False)
    
    # Predict
    y_pred = model.predict(val_generator, verbose=0)
    y_pred = np.argmax(y_pred, axis=1)
    
    # Store results
    all_y_true.extend(y_val)
    all_y_pred.extend(y_pred)
# Out:
# Evaluating Fold 1/10
#
# Evaluating Fold 2/10
#
# Evaluating Fold 3/10
#
# Evaluating Fold 4/10
#
# Evaluating Fold 5/10
#
# Evaluating Fold 6/10
#
# Evaluating Fold 7/10
#
# Evaluating Fold 8/10
#
# Evaluating Fold 9/10
#
# Evaluating Fold 10/10

# %%
# Convert nested arrays to 1D
all_y_true = np.array([x[0] if isinstance(x, (list, np.ndarray)) else x for x in all_y_true])
all_y_pred = np.array([x[0] if isinstance(x, (list, np.ndarray)) else x for x in all_y_pred])

# %%
print("Flattened shapes:")
print("y_true:", all_y_true.shape, "| Sample:", all_y_true[:5])
print("y_pred:", all_y_pred.shape, "| Sample:", all_y_pred[:5])
# Out:
# Flattened shapes:
# y_true: (2062,) | Sample: [0 0 0 0 0]
# y_pred: (2062,) | Sample: [0 0 0 0 0]

# %%
# Calculate confusion matrix
cm = confusion_matrix(all_y_true, all_y_pred)

# Plot with Seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=range(10), 
            yticklabels=range(10))
plt.title('Sign Language Digits Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
# Get precision, recall, f1-score (Classification report)
report = classification_report(all_y_true, all_y_pred, 
                               target_names=[str(i) for i in range(10)])
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       205
#            1       1.00      1.00      1.00       206
#            2       1.00      1.00      1.00       206
#            3       1.00      0.99      0.99       206
#            4       0.98      1.00      0.99       207
#            5       1.00      1.00      1.00       207
#            6       1.00      0.98      0.99       207
#            7       1.00      0.99      0.99       206
#            8       0.99      0.99      0.99       208
#            9       0.99      1.00      1.00       204
#
#     accuracy                           0.99      2062
#    macro avg       0.99      0.99      0.99      2062
# weighted avg       0.99      0.99      0.99      2062
