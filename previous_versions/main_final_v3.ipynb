# %% [markdown]
# # Final Main Implementation v.3

# %% [markdown]
# > This is a the main CNN implementation to recognize images of sign language digits.

# %%
# libraries:
import numpy as np
from sklearn.model_selection import train_test_split, KFold
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, GlobalAveragePooling2D
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# %% [markdown]
# ### Loading and preprocessing the data

# %%
# Defining a CNN model
def build_cnn(input_shape=(64, 64, 1), num_classes=10):
    model = models.Sequential([
        # Enhanced convolutional layers
        layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape),
        layers.BatchNormalization(),
        layers.Conv2D(32, (3, 3), activation='relu'),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),
        
        layers.Conv2D(64, (3, 3), activation='relu'),
        layers.BatchNormalization(),
        layers.Conv2D(64, (3, 3), activation='relu'),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),
        
        layers.Conv2D(128, (3, 3), activation='relu'),
        layers.BatchNormalization(),
        layers.GlobalAveragePooling2D(),
        layers.Dropout(0.5),
        
        layers.Dense(128, activation='relu'),
        layers.Dense(num_classes, activation='softmax')
    ])
    
    model.compile(
        optimizer=optimizers.Adam(learning_rate=0.001),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    
    return model

# %%
# Load images and labels
X = np.load('data/X.npy').astype('float32')
y = np.load('data/Y.npy')

# %%
# Add channel dimension (grayscale)
X = X.reshape(-1, 64, 64, 1)  # New shape: (2062, 64, 64, 1)

# %%
k = 5  # Typical value, but you can experiment
kf = KFold(n_splits=k, shuffle=True, random_state=42)

# %%
# Data Augmentation: helps increase the diversity of training data
# by applying random transformations like rotation and zoom
datagen = ImageDataGenerator(
    rotation_range=15,           # Randomly rotate images in the range (degrees)
    zoom_range=0.1,              # Randomly zoom images
    width_shift_range=0.1,       # Randomly shift images horizontally
    height_shift_range=0.1,       # Randomly shift images vertically
    fill_mode='nearest'
)

# %% [markdown]
# ### Main CNN Implementation with k-fold CV

# %%
# Lists to store history from each fold
accuracies = []
all_train_acc = []
all_val_acc = []
all_train_loss = []
all_val_loss = []

# %%
for train_index, val_index in kf.split(X):
    # Split data
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y[train_index], y[val_index]

    # Convert one-hot labels to integers 
    y_train = np.argmax(y_train, axis=1)
    y_val = np.argmax(y_val, axis=1)

    # Compute any statistics required for augmentation
    datagen.fit(X_train)
    
    # Create and train model (you'll need to reinitialize your model each time)
    model = build_cnn()  # Your model creation function
    history = model.fit(X_train, y_train, 
                       validation_data=(X_val, y_val),
                       epochs=30, batch_size=32)
    
    # Evaluate and store accuracy
    val_acc = model.evaluate(X_val, y_val)[1]
    accuracies.append(val_acc)

    # Store metrics
    all_train_acc.append(history.history['accuracy'])
    all_val_acc.append(history.history['val_accuracy'])
    all_train_loss.append(history.history['loss'])
    all_val_loss.append(history.history['val_loss'])
# Out:
# Epoch 1/30
# /Users/anthamorious/Library/Mobile Documents/com~apple~CloudDocs/University/University of Houston/Semesters/🎓 Spring 2025/🌹 COSC 4337 - Data Science II/Project/Final report/COSC4337-project-main/.venv/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 7s 120ms/step - accuracy: 0.2097 - loss: 2.1831 - val_accuracy: 0.1162 - val_loss: 2.3155
# Epoch 2/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 118ms/step - accuracy: 0.5456 - loss: 1.4069 - val_accuracy: 0.1162 - val_loss: 3.1224
# Epoch 3/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - accuracy: 0.7746 - loss: 0.7386 - val_accuracy: 0.1017 - val_loss: 4.3083
# Epoch 4/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - accuracy: 0.8480 - loss: 0.5021 - val_accuracy: 0.0969 - val_loss: 5.8034
# Epoch 5/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 120ms/step - accuracy: 0.9088 - loss: 0.3232 - val_accuracy: 0.1162 - val_loss: 9.5368
# Epoch 6/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 118ms/step - accuracy: 0.9197 - loss: 0.2618 - val_accuracy: 0.0969 - val_loss: 6.4424
# Epoch 7/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - accuracy: 0.9277 - loss: 0.2247 - val_accuracy: 0.1162 - val_loss: 6.6205
# Epoch 8/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - accuracy: 0.9437 - loss: 0.1805 - val_accuracy: 0.1840 - val_loss: 6.2819
# Epoch 9/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.9621 - loss: 0.1318 - val_accuracy: 0.1961 - val_loss: 5.4813
# Epoch 10/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 8s 148ms/step - accuracy: 0.9674 - loss: 0.1204 - val_accuracy: 0.3777 - val_loss: 1.9309
# Epoch 11/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 121ms/step - accuracy: 0.9511 - loss: 0.1434 - val_accuracy: 0.7724 - val_loss: 0.7197
# Epoch 12/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - accuracy: 0.9697 - loss: 0.1130 - val_accuracy: 0.6998 - val_loss: 0.8287
# Epoch 13/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 7s 125ms/step - accuracy: 0.9704 - loss: 0.0996 - val_accuracy: 0.9467 - val_loss: 0.2195
# Epoch 14/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - accuracy: 0.9797 - loss: 0.0684 - val_accuracy: 0.7990 - val_loss: 0.6619
# Epoch 15/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 123ms/step - accuracy: 0.9803 - loss: 0.0670 - val_accuracy: 0.9395 - val_loss: 0.1519
# Epoch 16/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - accuracy: 0.9810 - loss: 0.0654 - val_accuracy: 0.8814 - val_loss: 0.3642
# Epoch 17/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 119ms/step - accuracy: 0.9744 - loss: 0.0799 - val_accuracy: 0.9007 - val_loss: 0.3005
# Epoch 18/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 120ms/step - accuracy: 0.9845 - loss: 0.0552 - val_accuracy: 0.9564 - val_loss: 0.1289
# Epoch 19/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - accuracy: 0.9756 - loss: 0.0827 - val_accuracy: 0.8814 - val_loss: 0.3537
# Epoch 20/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - accuracy: 0.9838 - loss: 0.0492 - val_accuracy: 0.9831 - val_loss: 0.0504
# Epoch 21/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 120ms/step - accuracy: 0.9841 - loss: 0.0608 - val_accuracy: 0.9153 - val_loss: 0.2472
# Epoch 22/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - accuracy: 0.9888 - loss: 0.0430 - val_accuracy: 0.7893 - val_loss: 0.8709
# Epoch 23/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.9945 - loss: 0.0247 - val_accuracy: 0.9031 - val_loss: 0.3389
# Epoch 24/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9946 - loss: 0.0258 - val_accuracy: 0.9855 - val_loss: 0.0334
# Epoch 25/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 7s 130ms/step - accuracy: 0.9890 - loss: 0.0390 - val_accuracy: 0.9443 - val_loss: 0.2143
# Epoch 26/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 7s 125ms/step - accuracy: 0.9915 - loss: 0.0440 - val_accuracy: 0.9080 - val_loss: 0.2443
# Epoch 27/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.9905 - loss: 0.0399 - val_accuracy: 0.9661 - val_loss: 0.0982
# Epoch 28/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.9777 - loss: 0.0587 - val_accuracy: 0.9613 - val_loss: 0.1508
# Epoch 29/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.9888 - loss: 0.0362 - val_accuracy: 0.9831 - val_loss: 0.0459
# Epoch 30/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - accuracy: 0.9935 - loss: 0.0301 - val_accuracy: 0.9879 - val_loss: 0.0442
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9890 - loss: 0.0328
# Epoch 1/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - accuracy: 0.2084 - loss: 2.1756 - val_accuracy: 0.0969 - val_loss: 2.3645
# Epoch 2/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 123ms/step - accuracy: 0.5307 - loss: 1.3909 - val_accuracy: 0.1114 - val_loss: 2.4936
# Epoch 3/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - accuracy: 0.7192 - loss: 0.8632 - val_accuracy: 0.1114 - val_loss: 3.4759
# Epoch 4/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.8286 - loss: 0.5587 - val_accuracy: 0.0823 - val_loss: 4.7424
# Epoch 5/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 118ms/step - accuracy: 0.8862 - loss: 0.3813 - val_accuracy: 0.1186 - val_loss: 8.4213
# Epoch 6/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 118ms/step - accuracy: 0.9091 - loss: 0.2936 - val_accuracy: 0.0847 - val_loss: 7.0082
# Epoch 7/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 120ms/step - accuracy: 0.9266 - loss: 0.2518 - val_accuracy: 0.1598 - val_loss: 6.9848
# Epoch 8/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 118ms/step - accuracy: 0.9402 - loss: 0.1900 - val_accuracy: 0.1743 - val_loss: 7.3281
# Epoch 9/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 119ms/step - accuracy: 0.9620 - loss: 0.1467 - val_accuracy: 0.1017 - val_loss: 4.4210
# Epoch 10/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 119ms/step - accuracy: 0.9669 - loss: 0.1167 - val_accuracy: 0.3075 - val_loss: 2.5106
# Epoch 11/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 118ms/step - accuracy: 0.9623 - loss: 0.1136 - val_accuracy: 0.5811 - val_loss: 1.2165
# Epoch 12/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 120ms/step - accuracy: 0.9653 - loss: 0.1206 - val_accuracy: 0.3511 - val_loss: 3.1653
# Epoch 13/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 117ms/step - accuracy: 0.9657 - loss: 0.1108 - val_accuracy: 0.9056 - val_loss: 0.3194
# Epoch 14/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 118ms/step - accuracy: 0.9735 - loss: 0.0880 - val_accuracy: 0.8741 - val_loss: 0.3686
# Epoch 15/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 118ms/step - accuracy: 0.9847 - loss: 0.0653 - val_accuracy: 0.6852 - val_loss: 1.1756
# Epoch 16/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.9808 - loss: 0.0800 - val_accuracy: 0.9613 - val_loss: 0.1247
# Epoch 17/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 116ms/step - accuracy: 0.9692 - loss: 0.0921 - val_accuracy: 0.9419 - val_loss: 0.1887
# Epoch 18/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 117ms/step - accuracy: 0.9806 - loss: 0.0616 - val_accuracy: 0.9443 - val_loss: 0.2233
# Epoch 19/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - accuracy: 0.9902 - loss: 0.0472 - val_accuracy: 0.9661 - val_loss: 0.1122
# Epoch 20/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 117ms/step - accuracy: 0.9841 - loss: 0.0491 - val_accuracy: 0.9734 - val_loss: 0.1154
# Epoch 21/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 117ms/step - accuracy: 0.9920 - loss: 0.0334 - val_accuracy: 0.9855 - val_loss: 0.0697
# Epoch 22/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 117ms/step - accuracy: 0.9919 - loss: 0.0345 - val_accuracy: 0.9806 - val_loss: 0.0702
# Epoch 23/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.9905 - loss: 0.0344 - val_accuracy: 0.9056 - val_loss: 0.2850
# Epoch 24/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 117ms/step - accuracy: 0.9785 - loss: 0.0682 - val_accuracy: 0.7724 - val_loss: 0.9443
# Epoch 25/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.9923 - loss: 0.0359 - val_accuracy: 0.9613 - val_loss: 0.1199
# Epoch 26/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.9917 - loss: 0.0380 - val_accuracy: 0.9637 - val_loss: 0.1111
# Epoch 27/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.9895 - loss: 0.0458 - val_accuracy: 0.9492 - val_loss: 0.1825
# Epoch 28/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 116ms/step - accuracy: 0.9898 - loss: 0.0281 - val_accuracy: 0.9734 - val_loss: 0.1054
# Epoch 29/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 117ms/step - accuracy: 0.9814 - loss: 0.0532 - val_accuracy: 0.8232 - val_loss: 0.5836
# Epoch 30/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.9827 - loss: 0.0451 - val_accuracy: 0.9564 - val_loss: 0.1638
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9521 - loss: 0.1835
# Epoch 1/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - accuracy: 0.1943 - loss: 2.1635 - val_accuracy: 0.1772 - val_loss: 2.3574
# Epoch 2/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.5292 - loss: 1.3678 - val_accuracy: 0.1214 - val_loss: 2.4195
# Epoch 3/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 119ms/step - accuracy: 0.7088 - loss: 0.8755 - val_accuracy: 0.1092 - val_loss: 2.6077
# Epoch 4/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.8468 - loss: 0.5190 - val_accuracy: 0.0801 - val_loss: 2.8996
# Epoch 5/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 118ms/step - accuracy: 0.8773 - loss: 0.4015 - val_accuracy: 0.0801 - val_loss: 5.3588
# Epoch 6/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.9009 - loss: 0.3256 - val_accuracy: 0.1117 - val_loss: 4.1582
# Epoch 7/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 117ms/step - accuracy: 0.9158 - loss: 0.2474 - val_accuracy: 0.1262 - val_loss: 5.0149
# Epoch 8/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 118ms/step - accuracy: 0.9388 - loss: 0.2118 - val_accuracy: 0.1165 - val_loss: 3.4900
# Epoch 9/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.9480 - loss: 0.1644 - val_accuracy: 0.1141 - val_loss: 5.2503
# Epoch 10/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 118ms/step - accuracy: 0.9647 - loss: 0.1290 - val_accuracy: 0.5097 - val_loss: 1.4919
# Epoch 11/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.9746 - loss: 0.1158 - val_accuracy: 0.5291 - val_loss: 1.4555
# Epoch 12/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 117ms/step - accuracy: 0.9787 - loss: 0.0960 - val_accuracy: 0.9539 - val_loss: 0.1946
# Epoch 13/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 117ms/step - accuracy: 0.9829 - loss: 0.0761 - val_accuracy: 0.9660 - val_loss: 0.1885
# Epoch 14/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 116ms/step - accuracy: 0.9722 - loss: 0.0939 - val_accuracy: 0.9102 - val_loss: 0.2568
# Epoch 15/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.9821 - loss: 0.0840 - val_accuracy: 0.8786 - val_loss: 0.3329
# Epoch 16/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 116ms/step - accuracy: 0.9576 - loss: 0.1335 - val_accuracy: 0.9150 - val_loss: 0.2502
# Epoch 17/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 116ms/step - accuracy: 0.9844 - loss: 0.0542 - val_accuracy: 0.9757 - val_loss: 0.0708
# Epoch 18/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 117ms/step - accuracy: 0.9836 - loss: 0.0635 - val_accuracy: 0.9660 - val_loss: 0.1393
# Epoch 19/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.9930 - loss: 0.0334 - val_accuracy: 0.9636 - val_loss: 0.1019
# Epoch 20/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 118ms/step - accuracy: 0.9853 - loss: 0.0530 - val_accuracy: 0.9830 - val_loss: 0.0552
# Epoch 21/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 116ms/step - accuracy: 0.9826 - loss: 0.0489 - val_accuracy: 0.9709 - val_loss: 0.0695
# Epoch 22/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 116ms/step - accuracy: 0.9764 - loss: 0.0700 - val_accuracy: 0.9709 - val_loss: 0.0817
# Epoch 23/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 119ms/step - accuracy: 0.9782 - loss: 0.0623 - val_accuracy: 0.9684 - val_loss: 0.0650
# Epoch 24/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.9911 - loss: 0.0403 - val_accuracy: 0.9223 - val_loss: 0.2399
# Epoch 25/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 116ms/step - accuracy: 0.9873 - loss: 0.0425 - val_accuracy: 0.9417 - val_loss: 0.2217
# Epoch 26/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.9844 - loss: 0.0474 - val_accuracy: 0.9612 - val_loss: 0.0972
# Epoch 27/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 117ms/step - accuracy: 0.9922 - loss: 0.0318 - val_accuracy: 0.9296 - val_loss: 0.1810
# Epoch 28/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 118ms/step - accuracy: 0.9924 - loss: 0.0285 - val_accuracy: 0.9005 - val_loss: 0.3289
# Epoch 29/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.9926 - loss: 0.0348 - val_accuracy: 0.9830 - val_loss: 0.0504
# Epoch 30/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.9926 - loss: 0.0287 - val_accuracy: 0.9248 - val_loss: 0.2267
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9171 - loss: 0.2748
# Epoch 1/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - accuracy: 0.1970 - loss: 2.1589 - val_accuracy: 0.1359 - val_loss: 2.3343
# Epoch 2/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.5143 - loss: 1.5099 - val_accuracy: 0.0898 - val_loss: 2.3729
# Epoch 3/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.7598 - loss: 0.8131 - val_accuracy: 0.0728 - val_loss: 3.1291
# Epoch 4/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.8347 - loss: 0.5335 - val_accuracy: 0.0728 - val_loss: 3.6942
# Epoch 5/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.8625 - loss: 0.4483 - val_accuracy: 0.0850 - val_loss: 3.0916
# Epoch 6/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.8859 - loss: 0.3377 - val_accuracy: 0.1189 - val_loss: 3.3082
# Epoch 7/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 116ms/step - accuracy: 0.9267 - loss: 0.2588 - val_accuracy: 0.1408 - val_loss: 3.0649
# Epoch 8/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 116ms/step - accuracy: 0.9476 - loss: 0.2110 - val_accuracy: 0.1383 - val_loss: 2.7021
# Epoch 9/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.9540 - loss: 0.1599 - val_accuracy: 0.1626 - val_loss: 4.0590
# Epoch 10/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 116ms/step - accuracy: 0.9613 - loss: 0.1378 - val_accuracy: 0.2816 - val_loss: 2.9011
# Epoch 11/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.9587 - loss: 0.1576 - val_accuracy: 0.3495 - val_loss: 2.2137
# Epoch 12/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.9723 - loss: 0.1000 - val_accuracy: 0.8835 - val_loss: 0.3355
# Epoch 13/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 116ms/step - accuracy: 0.9724 - loss: 0.1052 - val_accuracy: 0.8762 - val_loss: 0.4209
# Epoch 14/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.9736 - loss: 0.1007 - val_accuracy: 0.5655 - val_loss: 1.3599
# Epoch 15/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.9770 - loss: 0.0862 - val_accuracy: 0.9248 - val_loss: 0.2906
# Epoch 16/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.9783 - loss: 0.0837 - val_accuracy: 0.9709 - val_loss: 0.1039
# Epoch 17/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.9869 - loss: 0.0699 - val_accuracy: 0.9490 - val_loss: 0.1114
# Epoch 18/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.9841 - loss: 0.0553 - val_accuracy: 0.8956 - val_loss: 0.3684
# Epoch 19/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.9859 - loss: 0.0531 - val_accuracy: 0.9854 - val_loss: 0.0521
# Epoch 20/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.9845 - loss: 0.0526 - val_accuracy: 0.7549 - val_loss: 1.3630
# Epoch 21/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.9779 - loss: 0.0715 - val_accuracy: 0.9175 - val_loss: 0.2741
# Epoch 22/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 116ms/step - accuracy: 0.9861 - loss: 0.0479 - val_accuracy: 0.9709 - val_loss: 0.0989
# Epoch 23/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 116ms/step - accuracy: 0.9850 - loss: 0.0500 - val_accuracy: 0.9806 - val_loss: 0.0494
# Epoch 24/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 116ms/step - accuracy: 0.9924 - loss: 0.0362 - val_accuracy: 0.9320 - val_loss: 0.1975
# Epoch 25/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 116ms/step - accuracy: 0.9843 - loss: 0.0508 - val_accuracy: 0.7257 - val_loss: 1.0993
# Epoch 26/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.9748 - loss: 0.0795 - val_accuracy: 0.9636 - val_loss: 0.1353
# Epoch 27/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.9899 - loss: 0.0364 - val_accuracy: 0.8714 - val_loss: 0.4394
# Epoch 28/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.9929 - loss: 0.0270 - val_accuracy: 0.9612 - val_loss: 0.0969
# Epoch 29/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.9909 - loss: 0.0296 - val_accuracy: 0.9150 - val_loss: 0.2885
# Epoch 30/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 116ms/step - accuracy: 0.9828 - loss: 0.0539 - val_accuracy: 0.9733 - val_loss: 0.1161
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9807 - loss: 0.0956
# Epoch 1/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 7s 114ms/step - accuracy: 0.2217 - loss: 2.1385 - val_accuracy: 0.0898 - val_loss: 2.4405
# Epoch 2/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.5208 - loss: 1.4164 - val_accuracy: 0.0898 - val_loss: 2.3900
# Epoch 3/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.7602 - loss: 0.7999 - val_accuracy: 0.0850 - val_loss: 4.6071
# Epoch 4/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.8475 - loss: 0.5063 - val_accuracy: 0.0850 - val_loss: 4.5988
# Epoch 5/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.8829 - loss: 0.3806 - val_accuracy: 0.0898 - val_loss: 6.8331
# Epoch 6/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.9334 - loss: 0.2647 - val_accuracy: 0.1456 - val_loss: 5.1710
# Epoch 7/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.9181 - loss: 0.2479 - val_accuracy: 0.0898 - val_loss: 6.8233
# Epoch 8/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.9505 - loss: 0.1867 - val_accuracy: 0.0898 - val_loss: 4.4378
# Epoch 9/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.9647 - loss: 0.1222 - val_accuracy: 0.2597 - val_loss: 2.8831
# Epoch 10/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.9676 - loss: 0.1202 - val_accuracy: 0.3689 - val_loss: 1.6601
# Epoch 11/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.9635 - loss: 0.1228 - val_accuracy: 0.6553 - val_loss: 0.8375
# Epoch 12/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.9696 - loss: 0.0943 - val_accuracy: 0.7694 - val_loss: 0.7107
# Epoch 13/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.9766 - loss: 0.0725 - val_accuracy: 0.6189 - val_loss: 1.4859
# Epoch 14/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.9815 - loss: 0.0736 - val_accuracy: 0.9223 - val_loss: 0.2385
# Epoch 15/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.9781 - loss: 0.0754 - val_accuracy: 0.7961 - val_loss: 0.6770
# Epoch 16/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.9726 - loss: 0.0717 - val_accuracy: 0.8617 - val_loss: 0.4894
# Epoch 17/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.9867 - loss: 0.0505 - val_accuracy: 0.9757 - val_loss: 0.0960
# Epoch 18/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.9854 - loss: 0.0530 - val_accuracy: 0.9733 - val_loss: 0.1339
# Epoch 19/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.9773 - loss: 0.0656 - val_accuracy: 0.9709 - val_loss: 0.1287
# Epoch 20/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.9862 - loss: 0.0534 - val_accuracy: 0.7209 - val_loss: 0.9042
# Epoch 21/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.9833 - loss: 0.0567 - val_accuracy: 0.9684 - val_loss: 0.1275
# Epoch 22/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.9949 - loss: 0.0254 - val_accuracy: 0.9005 - val_loss: 0.3306
# Epoch 23/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.9957 - loss: 0.0290 - val_accuracy: 0.9005 - val_loss: 0.3382
# Epoch 24/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.9868 - loss: 0.0470 - val_accuracy: 0.9660 - val_loss: 0.1279
# Epoch 25/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.9968 - loss: 0.0186 - val_accuracy: 0.9733 - val_loss: 0.0990
# Epoch 26/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.9906 - loss: 0.0350 - val_accuracy: 0.9879 - val_loss: 0.0852
# Epoch 27/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.9912 - loss: 0.0324 - val_accuracy: 0.9563 - val_loss: 0.1939
# Epoch 28/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 7s 138ms/step - accuracy: 0.9943 - loss: 0.0261 - val_accuracy: 0.9854 - val_loss: 0.0687
# Epoch 29/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 7s 138ms/step - accuracy: 0.9957 - loss: 0.0184 - val_accuracy: 0.7087 - val_loss: 1.7016
# Epoch 30/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 9s 168ms/step - accuracy: 0.9916 - loss: 0.0282 - val_accuracy: 0.9320 - val_loss: 0.2817
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9494 - loss: 0.3028

# %% [markdown]
# ### Viewing CNN Statistics

# %%
def plot_avg_accuracy(train_acc, val_acc):
    avg_train_acc = np.mean(train_acc, axis=0)
    avg_val_acc = np.mean(val_acc, axis=0)
    
    plt.figure(figsize=(10, 5))
    plt.plot(avg_train_acc, label='Training Accuracy')
    plt.plot(avg_val_acc, label='Validation Accuracy')
    plt.title('Average Training & Validation Accuracy Across Folds')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
def plot_avg_loss(train_loss, val_loss):
    avg_train_loss = np.mean(train_loss, axis=0)
    avg_val_loss = np.mean(val_loss, axis=0)
    
    plt.figure(figsize=(10, 5))
    plt.plot(avg_train_loss, label='Training Loss')
    plt.plot(avg_val_loss, label='Validation Loss')
    plt.title('Average Training & Validation Loss Across Folds')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
def plot_individual_folds(metric, title, ylabel):
    plt.figure(figsize=(10, 5))
    for i, fold_metric in enumerate(metric):
        plt.plot(fold_metric, label=f'Fold {i+1}')
    plt.title(title)
    plt.xlabel('Epoch')
    plt.ylabel(ylabel)
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
def plot_overlaid_folds(train_metric, val_metric, metric_name):
    plt.figure(figsize=(12, 6))
    
    # Plot all training metrics
    for i, fold_metric in enumerate(train_metric):
        plt.plot(fold_metric, color='blue', alpha=0.2, linestyle='-')
    
    # Plot all validation metrics
    for i, fold_metric in enumerate(val_metric):
        plt.plot(fold_metric, color='orange', alpha=0.2, linestyle='-')
    
    # Plot averages
    plt.plot(np.mean(train_metric, axis=0), color='blue', 
             linewidth=2, label='Avg Training')
    plt.plot(np.mean(val_metric, axis=0), color='orange', 
             linewidth=2, label='Avg Validation')
    
    plt.title(f'Training & Validation {metric_name} Across Folds')
    plt.xlabel('Epoch')
    plt.ylabel(metric_name)
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
print(f"Average validation accuracy: {np.mean(accuracies):.2%}")
# Out:
# Average validation accuracy: 95.49%

# %%
# Plotting average accuracy
plot_avg_accuracy(all_train_acc, all_val_acc)

# %%
# Plot individual folds accuracy
plot_individual_folds(all_train_acc, 'Training Accuracy per Fold', 'Accuracy')
plot_individual_folds(all_val_acc, 'Validation Accuracy per Fold', 'Accuracy')

# %%
# Plotting average loss
plot_avg_loss(all_train_loss, all_val_loss)

# %%
# Plot individual folds loss
plot_individual_folds(all_train_loss, 'Training Loss per Fold', 'Loss')
plot_individual_folds(all_val_loss, 'Validation Loss per Fold', 'Loss')

# %%
plot_overlaid_folds(all_train_acc, all_val_acc, 'Accuracy')

# %%
plot_overlaid_folds(all_train_loss, all_val_loss, 'Loss')
